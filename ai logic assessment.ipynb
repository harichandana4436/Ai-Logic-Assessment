# %% [markdown]
# ## Problem 3

# %%
b="abcdef"
a=b.split()
print(a)
s="".split()
print(s)
t=""
for ch in a:
    if ch!=s:
        s.append(ch)
    print(s)
# Out:
# ['abcdef']
# []
# ['abcdef']

# %% [markdown]
# ## Problem 2

# %%
a=[2,1,5,1,3,2]
print(a)
s=[]
total=0
for i in range(len(a)):
    for j in range(i+1):
        for k in range(i+2):
            if a[i]>a[j]>a[k]:
                total=a[i]+a[j]+a[k]
                a.append(total)
print(total)
# Out:
# [2, 1, 5, 1, 3, 2]
# 6

# %% [markdown]
# ## problem 1

# %%
a=[12345]
print(a)
s=[]
if a[0]==a[2]:
    s.appned(s)
print(a)
# Out:
# [12345]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[169], line 4
#       2 print(a)
#       3 s=[]
# ----> 4 if a[0]==a[2]:
#       5     s.appned(s)
#       6 print(a)
#
# IndexError: list index out of range
